# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('depression_anxiety_data.csv' )
df.filter(["id", "school_year", "age"]).head()
# Out:
#    id  school_year  age
# 0   1            1   19
# 1   2            1   18
# 2   3            1   19
# 3   4            1   18
# 4   5            1   18

# %%
df['suicidal'].value_counts()
# Out:
# False    713
# True      69
# Name: suicidal, dtype: int64

# %%
df['sleepiness'].value_counts()
# Out:
# False    634
# True     141
# Name: sleepiness, dtype: int64

# %%
#DataFrame Index
df.set_index('anxiousness', inplace=True)
df.index
# Out:
# Index([ True, False, False,  True,  True, False, False, False, False, False,
#        ...
#        False, False, False, False, False, False, False, False,  True, False],
#       dtype='object', name='anxiousness', length=783)

# %%
df
# Out:
#               id  school_year  age  gender        bmi          who_bmi  \
# anxiousness
# True           1            1   19    male  33.333333  Class I Obesity
# False          2            1   18    male  19.841270           Normal
# False          3            1   19    male  25.102391       Overweight
# True           4            1   18  female  23.738662           Normal
# True           5            1   18    male  25.617284       Overweight
# ...          ...          ...  ...     ...        ...              ...
# False        779            4   24  female  21.096191           Normal
# False        780            4   22    male  25.308642       Overweight
# False        781            4   22    male  22.720438           Normal
# True         782            4   22  female  23.033168           Normal
# False        783            4   22    male  22.598140           Normal
#
#              phq_score depression_severity depressiveness suicidal  \
# anxiousness
# ...

# %%
#only the female in gender column
female = df[df.gender == 'female']
female
# Out:
#               id  school_year  age  gender        bmi       who_bmi  \
# anxiousness
# True           4            1   18  female  23.738662        Normal
# False         12            1   18  female   0.000000  Not Availble
# True          17            1   18  female  22.100290        Normal
# False         18            1   18  female  24.034610        Normal
# True          22            1   18  female  26.562500    Overweight
# ...          ...          ...  ...     ...        ...           ...
# False        772            4   22  female  22.038567        Normal
# False        774            4   22  female  18.066167   Underweight
# False        775            4   23  female  20.202020        Normal
# False        779            4   24  female  21.096191        Normal
# True         782            4   22  female  23.033168        Normal
#
#              phq_score depression_severity depressiveness suicidal  \
# anxiousness
# ...

# %%
df.dtypes
# Out:
# id                        int64
# school_year               int64
# age                       int64
# gender                   object
# bmi                     float64
# who_bmi                  object
# phq_score                 int64
# depression_severity      object
# depressiveness           object
# suicidal                 object
# depression_diagnosis     object
# depression_treatment     object
# gad_score                 int64
# anxiety_severity         object
# anxiety_diagnosis        object
# anxiety_treatment        object
# epworth_score           float64
# sleepiness               object
# dtype: object

# %%
df[['id']] = df[['id']].astype("float")
df
# Out:
#                 id  school_year  age  gender        bmi          who_bmi  \
# anxiousness
# True           1.0            1   19    male  33.333333  Class I Obesity
# False          2.0            1   18    male  19.841270           Normal
# False          3.0            1   19    male  25.102391       Overweight
# True           4.0            1   18  female  23.738662           Normal
# True           5.0            1   18    male  25.617284       Overweight
# ...            ...          ...  ...     ...        ...              ...
# False        779.0            4   24  female  21.096191           Normal
# False        780.0            4   22    male  25.308642       Overweight
# False        781.0            4   22    male  22.720438           Normal
# True         782.0            4   22  female  23.033168           Normal
# False        783.0            4   22    male  22.598140           Normal
#
#              phq_score depression_severity depressiveness suicidal  \
# ...

# %%
df.sort_values(by=['phq_score'])
# Out:
#                 id  school_year  age  gender        bmi           who_bmi  \
# anxiousness
# False         25.0            1   18    male  22.758307            Normal
# False        566.0            3   21    male  24.056935            Normal
# False        531.0            3   21    male  26.528510        Overweight
# False        542.0            3   24    male  29.053288        Overweight
# False         40.0            1   18    male  20.571429            Normal
# ...            ...          ...  ...     ...        ...               ...
# True         342.0            2   20  female  20.202020            Normal
# True         761.0            4   22  female  24.919900            Normal
# True         299.0            2   19  female  16.896235       Underweight
# True         227.0            1   24    male  35.671819  Class II Obesity
# True         245.0            1   19  female  18.424036       Underweight
#
# ...

# %%
pd.unique(df['who_bmi'])
# Out:
# array(['Class I Obesity', 'Normal', 'Overweight', 'Not Availble',
#        'Class III Obesity', 'Underweight', 'Class II Obesity'],
#       dtype=object)

# %%
df['gad_score'].describe()
# Out:
# count    783.000000
# mean       6.810983
# std        4.727352
# min        0.000000
# 25%        3.000000
# 50%        6.000000
# 75%        9.000000
# max       21.000000
# Name: gad_score, dtype: float64

# %%
species_counts = df.groupby('suicidal')['age'].count()
print(species_counts)
# Out:
# suicidal
# False    713
# True      69
# Name: age, dtype: int64

# %%
# %matplotlib inline
species_counts.plot(kind='bar');

# %%
sns.pairplot(df , x_vars=['id', 'school_year','age'], y_vars='phq_score', height=7, aspect=0.7, kind='reg')

# %%
df.plot(x ='age', y='gad_score' , style='o')
plt.title('ages of people that got a gad_score')
plt.x1lable('age')
plt.ylable('gad_score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [68], in <cell line: 3>()
#       1 df.plot(x ='age', y='gad_score' , style='o')
#       2 plt.title('ages of people that got a gad_score')
# ----> 3 plt.x1lable('age')
#       4 plt.ylable('gad_score')
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'x1lable'
